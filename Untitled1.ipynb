# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
# %matplotlib inline

# %%
df=pd.read_csv('salary_prediction_dataset.csv')
df.head()
# Out:
#    YearsExperience        Salary
# 0         8.116262  41469.816295
# 1        19.063572  88641.137315
# 2        14.907885  76440.413727
# 3        12.374511  64925.484725
# 4         3.964354  22620.723082

# %%
print(df.isnull().sum())

plt.figure(figsize=(8,5))
sns.scatterplot(x=df['YearsExperience'],y=df['Salary'])
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('Years of Experience vs Salary')
plt.show()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
# spliting the data set into fearures (x) and target variables(y)
x= df[['YearsExperience']] #independent variable
y= df[['Salary']] #dependent variable

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, random_state=42)

x_train.shape, x_test.shape
# Out:
# ((800, 1), (200, 1))

# %%
# creatring and training the simple regression model
model=LinearRegression()
model.fit(x_train, y_train)

#display model parimeters
print(f"Intercept: {model.intercept_}")
print(f"Coefficient: {model.coef_[0]}")
# Out:
# Intercept: [995.57704648]
# Coefficient: [4953.70941726]

# %%
y_pred=model.predict(x_test)
results = pd.DataFrame({'Actual Salary': y_test.values.ravel(), 'Predicted Salary': y_pred.ravel()}) # Changed y_pred to y_pred.ravel() to flatten the array.
results.head()
# Out:
#    Actual Salary  Predicted Salary
# 0   46144.843128      41798.916309
# 1   85731.005173      82808.016799
# 2   55059.748116      49496.929481
# 3   42143.595304      39465.280850
# 4   88585.759395      95369.573814

# %%
plt.figure(figsize=(8, 5)) # Changed figsize to a tuple (width, height)
plt.scatter(x_train, y_train, color='blue', label="Actual salary (Training)")
plt.plot(x_train, model.predict(x_train), color='red', label="Regressiuon")
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.title('years of experience vs salary')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_test,y_test, color='green',label="Actual Salary(Test Data)") # Changed X_test to x_test
plt.scatter(x_test, y_pred, color='red', label="Predicted Salary(Test Data)") # Changed X_test to x_test
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.title('Salary Prediction(Test Data)')
plt.legend()
plt.show()
plt.plot(x_train['YearsExperience'], model.predict(x_train), color='red') # Changed X_train to x_train

# %%
mae=mean_absolute_error(y_test,y_pred)
mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print("Mean Absolute Error (MAE):",{mae})
print("Mean Squared Error (MSE):",{mse})
print("R2 score: {r2}")
# Out:
# Mean Absolute Error (MAE): {3602.3955438952066}
# Mean Squared Error (MSE): {21434311.66454385}
# R2 score: {r2}

# %%
experience = float(input("Enter years of experience: "))
predicted_salary = model.predict([[experience]])[0]
print(f"Predicted Salary for {experience} years of experience: {predicted_salary[0]}")
# Out:
# Enter years of experience: 2
# Predicted Salary for 2.0 years of experience: 10902.995881002138
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
